# %% [markdown]
# <hr>
#
# <h1 align="left">Kaggle Learn · Certificaciones</h1>
#
# <p align="center">
#   Cuadernillo de cursos, badges y certificaciones obtenidas en Kaggle Learn,
#   enfocado en el aprendizaje práctico de ciencia de datos y machine learning.
# </p>
#
# <p align="center">
#   Este documento recopila la formación completada, las competencias adquiridas
#   y su aplicación en el análisis y preparación de datos reales.
# </p>
#
# <p align="center">
#   <em>Contenido organizado con fines de documentación y portafolio profesional.</em>
# </p>
#
# <hr>

# %% [markdown]
# <h1 align="center">Curso Pandas</h1>

# %% [markdown]
# ![wtf](assets/enserio.png)

# %% [markdown]
# Curso enfocado en el uso de **Pandas** para la manipulación y análisis eficiente de datos en Python, incluyendo limpieza de datos, transformación de datasets y preparación de información para modelos de machine learning y análisis exploratorio.

# %% [markdown]
# ---
#
# <p align="center">
#   <img src="assets/separador.png" alt="Separador" width=300"/>
# </p>
#
# ---

# %% [markdown]
# <h1 align="center">Curso Data Cleaning</h1>

# %% [markdown]
# ![Data Cleaning Badge](assets/DataCleaning.png)

# %% [markdown]
# Curso enfocado en técnicas de **limpieza y preparación de datos** con Python, incluyendo el tratamiento de valores faltantes, estandarización de formatos, corrección de inconsistencias y preparación de datos reales para su análisis y modelado.

# %% [markdown]
# ---
#
# <p align="center">
#   <img src="assets/separador.png" alt="Separador" width=300"/>
# </p>
#
# ---

# %% [markdown]
# <h1 align="center">Curso Data Visualization</h1>

# %% [markdown]
# ![Data Visualization Badge](assets/DataVisualization.png)

# %% [markdown]
# Curso enfocado en la **visualización de datos** para la comunicación efectiva de insights, utilizando gráficos y representaciones visuales que facilitan la interpretación de patrones, tendencias y resultados de análisis.

# %% [markdown]
# ---
#
# <p align="center">
#   <img src="assets/separador.png" alt="Separador" width=300"/>
# </p>
#
# ---

# %% [markdown]
# <h1 align="center">Curso Geospatial Analysis</h1>

# %% [markdown]
# ![Geospatial Analysis Badge](assets/GeospatialAnalysis.png)

# %% [markdown]
# Curso enfocado en el **análisis de datos geoespaciales**, incluyendo el uso de coordenadas, mapas y visualizaciones espaciales para identificar patrones geográficos y apoyar la toma de decisiones basada en datos.
