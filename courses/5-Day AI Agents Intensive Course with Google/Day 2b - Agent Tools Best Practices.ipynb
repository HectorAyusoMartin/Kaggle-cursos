# %% [markdown]
# # Day 2b - Agent Tools Best Practices #

# %% [markdown]
# > ⚠️ **Nota importante**
# >  A continuación se muestra un proceso secuencial inicial, a nivel de configuración, que es necesario realizar antes de empezar a trabajar con los Agentes. Se importan librerias de ADK necesarias con sus respectivos componentes, se crean las Helper Functions y las opciones de configuración de Retry.

# %%
import uuid
from google.genai import types

from google.adk.agents import LlmAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import Runner
from google.adk.sessions import InMemorySessionService

from google.adk.tools.mcp_tool.mcp_toolset import McpToolset
from google.adk.tools.tool_context import ToolContext
from google.adk.tools.mcp_tool.mcp_session_manager import StdioConnectionParams
from mcp import StdioServerParameters

from google.adk.apps.app import App, ResumabilityConfig
from google.adk.tools.function_tool import FunctionTool

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %%
retry_config = types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504],  # Retry on these HTTP errors
)
print("✅Retry Options configured sucessfully.")
# Out:
# ✅Retry Options configured sucessfully.

# %% [markdown]
#
# > ⚠️ **Nota importante**
# >  Fin de confiduraciones e integraciones.

# %% [markdown]
# ## Sección 2: Protocolo de Contexto del Modelo (Model Context Protocol)
#
# Hasta ahora, has aprendido a crear funciones personalizadas para tus agentes. Sin embargo, conectarse a sistemas externos (GitHub, bases de datos, Slack) requiere escribir y mantener clientes de API.
#
# El ***Model Context Protocol (MCP)*** es un estándar abierto que permite a los agentes usar integraciones creadas por la comunidad. En lugar de escribir tus propias integraciones y clientes de API, simplemente conéctate a un servidor MCP existente.
#
# MCP permite a los agentes:
#
# - ✅ Acceder a datos externos y en tiempo real desde bases de datos, APIs y servicios sin necesidad de escribir código de integración personalizado
# - ✅ Aprovechar herramientas creadas por la comunidad con interfaces estandarizadas
# - ✅ Escalar capacidades conectándose a múltiples servidores especializados

# %% [markdown]
#
# > ⚠️ **Nota importante**
# >  Conectando a MCP.

# %% [markdown]
# Uso de MCP con tu agente
#
# El flujo de trabajo es simple:
#
# Elegir un servidor MCP y una tool
#
# Crear el conjunto de tools MCP (configurar la conexión)
#
# Añadirlo a tu agente
#
# Ejecutar y probar el agente
#
# ***Paso 1: Elegir un servidor MCP***
#
# Para esta demostración, usaremos el Everything MCP Server, un paquete npm (@modelcontextprotocol/server-everything) diseñado para probar integraciones MCP.
#
# Este servidor proporciona una tool llamada getTinyImage, que devuelve una imagen de prueba sencilla (16×16 píxeles, codificada en Base64).
# Puedes encontrar más servidores en: modelcontextprotocol.io/examples
#
# ‼️ NOTA: Este es un servidor de demostración para aprender MCP.
# En producción, usarías servidores para Google Maps, Slack, Discord, etc.
#
# ***Paso 2: Crear el conjunto de tools MCP***
#
# El McpToolset se utiliza para integrar un agente de ADK con un servidor MCP.
#
# Qué hace el código:
#
# Usa npx (ejecutor de paquetes de Node) para ejecutar el servidor MCP
#
# Se conecta a @modelcontextprotocol/server-everything
#
# Filtra para usar solo la tool getTinyImage (el servidor tiene más, pero solo necesitamos esta)

# %%
# MCP integration with Everything Server
mcp_image_server = McpToolset(
    connection_params=StdioConnectionParams(
        server_params=StdioServerParameters(
            command="npx",  # Run MCP server via npx
            args=[
                "-y",  # Argument for npx to auto-confirm install
                "@modelcontextprotocol/server-everything",
            ],
            tool_filter=["getTinyImage"],
        ),
        timeout=30,
    )
)

print("✅ MCP Tool created")
# Out:
# ✅ MCP Tool created

# %% [markdown]
# ***Paso 3: Añadir la tool MCP al agente***
#
# Vamos a añadir el mcp_server al arreglo (lista) de tools del agente y actualizar las instrucciones del agente para manejar solicitudes de generación de imágenes pequeñas (tiny images).

# %%
# Create image agent with MCP integration
image_agent = LlmAgent(
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    name="image_agent",
    instruction="Use the MCP Tool to generate images for user queries",
    tools=[mcp_image_server],
)

# %% [markdown]
# ***Creamos el Runner***

# %%
from google.adk.runners import InMemoryRunner

runner = InMemoryRunner(agent=image_agent)

# %% [markdown]
# ***Testeamos el Agente***

# %%
response = await runner.run_debug("Proporciona una imagen pequeña de ejemplo", verbose=True)
# Out:
#  ### Continue session: debug_session_id
#
# User > Proporciona una imagen pequeña de ejemplo
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~\kaggle-adk\Lib\site-packages\mcp\os\win32\utilities.py:169, in create_windows_process(command, args, env, errlog, cwd)
#     167 try:
#     168     # First try using anyio with Windows-specific flags to hide console window
# --> 169     process = await anyio.open_process(
#     170         [command, *args],
#     171         env=env,
#     172         # Ensure we don't create console windows for each process
#     173         creationflags=subprocess.CREATE_NO_WINDOW  # type: ignore
#     174         if hasattr(subprocess, "CREATE_NO_WINDOW")
#     175         else 0,
#     176         stderr=errlog,
#     177         cwd=cwd,
#     178     )
#     179 except NotImplementedError:
#     180     # If Windows doesn't support async subprocess creation, use fallback
#
# File ~\kaggle-adk\Lib\site-packages\anyio\_core\_subprocesses.py:190, in open_process(command, stdin, stdout, stderr, cwd, env, startupinfo, creationflags, start_new_session, pass_fds, user, group, extra_groups, umask)
#     188     kwargs["umask"] = umask
# --> 190 return await get_async_backend().open_process(
#     191     command,
#     192     stdin=stdin,
#     193     stdout=stdout,
#     194     stderr=stderr,
#     195     cwd=cwd,
#     196     env=env,
#     197     startupinfo=startupinfo,
#     198     creationflags=creationflags,
#     199     start_new_session=start_new_session,
#     200     pass_fds=pass_fds,
#     201     **kwargs,
#     202 )
#
# File ~\kaggle-adk\Lib\site-packages\anyio\_backends\_asyncio.py:2628, in AsyncIOBackend.open_process(cls, command, stdin, stdout, stderr, **kwargs)
#    2627 else:
# -> 2628     process = await asyncio.create_subprocess_exec(
#    2629         *command,
#    2630         stdin=stdin,
#    2631         stdout=stdout,
#    2632         stderr=stderr,
#    2633         **kwargs,
#    2634     )
#    2636 stdin_stream = StreamWriterWrapper(process.stdin) if process.stdin else None
#
# File ~\miniconda3\Lib\asyncio\subprocess.py:224, in create_subprocess_exec(program, stdin, stdout, stderr, limit, *args, **kwds)
#     222 protocol_factory = lambda: SubprocessStreamProtocol(limit=limit,
#     223                                                     loop=loop)
# --> 224 transport, protocol = await loop.subprocess_exec(
#     225     protocol_factory,
#     226     program, *args,
#     227     stdin=stdin, stdout=stdout,
#     228     stderr=stderr, **kwds)
#     229 return Process(transport, protocol, loop)
#
# File ~\miniconda3\Lib\asyncio\base_events.py:1802, in BaseEventLoop.subprocess_exec(self, protocol_factory, program, stdin, stdout, stderr, universal_newlines, shell, bufsize, encoding, errors, text, *args, **kwargs)
#    1801     self._log_subprocess(debug_log, stdin, stdout, stderr)
# -> 1802 transport = await self._make_subprocess_transport(
#    1803     protocol, popen_args, False, stdin, stdout, stderr,
#    1804     bufsize, **kwargs)
#    1805 if self._debug and debug_log is not None:
#
# File ~\miniconda3\Lib\asyncio\base_events.py:539, in BaseEventLoop._make_subprocess_transport(self, protocol, args, shell, stdin, stdout, stderr, bufsize, extra, **kwargs)
#     538 """Create subprocess transport."""
# --> 539 raise NotImplementedError
#
# NotImplementedError:
#
# During handling of the above exception, another exception occurred:
#
# UnsupportedOperation                      Traceback (most recent call last)
# File ~\kaggle-adk\Lib\site-packages\mcp\os\win32\utilities.py:209, in _create_windows_fallback_process(command, args, env, errlog, cwd)
#     207 try:
#     208     # Try launching with creationflags to avoid opening a new console window
# --> 209     popen_obj = subprocess.Popen(
#     210         [command, *args],
#     211         stdin=subprocess.PIPE,
#     212         stdout=subprocess.PIPE,
#     213         stderr=errlog,
#     214         env=env,
#     215         cwd=cwd,
#     216         bufsize=0,  # Unbuffered output
#     217         creationflags=getattr(subprocess, "CREATE_NO_WINDOW", 0),
#     218     )
#     219 except Exception:
#     220     # If creationflags failed, fallback without them
#
# File ~\miniconda3\Lib\subprocess.py:1005, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#     988 # Input and output objects. The general principle is like
#     989 # this:
#     990 #
#    (...)   1000 # are -1 when not using PIPEs. The child objects are -1
#    1001 # when not redirecting.
#    1003 (p2cread, p2cwrite,
#    1004  c2pread, c2pwrite,
# -> 1005  errread, errwrite) = self._get_handles(stdin, stdout, stderr)
#    1007 # From here on, raising exceptions may cause file descriptor leakage
#    1008
#    1009 # We wrap OS handles *before* launching the child, otherwise a
#    1010 # quickly terminating child could make our fds unwrappable
#    1011 # (see #8458).
#
# File ~\miniconda3\Lib\subprocess.py:1422, in Popen._get_handles(self, stdin, stdout, stderr)
#    1420 else:
#    1421     # Assuming file-like object
# -> 1422     errwrite = msvcrt.get_osfhandle(stderr.fileno())
#    1423 errwrite = self._make_inheritable(errwrite)
#
# File ~\kaggle-adk\Lib\site-packages\ipykernel\iostream.py:372, in OutStream.fileno(self)
#     371 msg = "fileno"
# --> 372 raise io.UnsupportedOperation(msg)
#
# UnsupportedOperation: fileno
#
# During handling of the above exception, another exception occurred:
#
# UnsupportedOperation                      Traceback (most recent call last)
# File ~\kaggle-adk\Lib\site-packages\google\adk\tools\mcp_tool\mcp_session_manager.py:341, in MCPSessionManager.create_session(self, headers)
#     339 client = self._create_client(merged_headers)
# --> 341 transports = await asyncio.wait_for(
#     342     exit_stack.enter_async_context(client),
#     343     timeout=timeout_in_seconds,
#     344 )
#     345 # The streamable http client returns a GetSessionCallback in addition to the
#     346 # read/write MemoryObjectStreams needed to build the ClientSession, we limit
#     347 # then to the two first values to be compatible with all clients.
#
# File ~\miniconda3\Lib\asyncio\tasks.py:507, in wait_for(fut, timeout)
#     506 async with timeouts.timeout(timeout):
# --> 507     return await fut
#
# File ~\miniconda3\Lib\contextlib.py:668, in AsyncExitStack.enter_async_context(self, cm)
#     665     raise TypeError(f"'{cls.__module__}.{cls.__qualname__}' object does "
#     666                     f"not support the asynchronous context manager protocol"
#     667                    ) from None
# --> 668 result = await _enter(cm)
#     669 self._push_async_cm_exit(cm, _exit)
#
# File ~\miniconda3\Lib\contextlib.py:214, in _AsyncGeneratorContextManager.__aenter__(self)
#     213 try:
# --> 214     return await anext(self.gen)
#     215 except StopAsyncIteration:
#
# File ~\kaggle-adk\Lib\site-packages\mcp\client\stdio\__init__.py:124, in stdio_client(server, errlog)
#     123     # Open process with stderr piped for capture
# --> 124     process = await _create_platform_compatible_process(
#     125         command=command,
#     126         args=server.args,
#     127         env=({**get_default_environment(), **server.env} if server.env is not None else get_default_environment()),
#     128         errlog=errlog,
#     129         cwd=server.cwd,
#     130     )
#     131 except OSError:
#     132     # Clean up streams if process creation fails
#
# File ~\kaggle-adk\Lib\site-packages\mcp\client\stdio\__init__.py:249, in _create_platform_compatible_process(command, args, env, errlog, cwd)
#     248 if sys.platform == "win32":  # pragma: no cover
# --> 249     process = await create_windows_process(command, args, env, errlog, cwd)
#     250 else:
#
# File ~\kaggle-adk\Lib\site-packages\mcp\os\win32\utilities.py:181, in create_windows_process(command, args, env, errlog, cwd)
#     179 except NotImplementedError:
#     180     # If Windows doesn't support async subprocess creation, use fallback
# --> 181     process = await _create_windows_fallback_process(command, args, env, errlog, cwd)
#     182 except Exception:
#     183     # Try again without creation flags
#
# File ~\kaggle-adk\Lib\site-packages\mcp\os\win32\utilities.py:221, in _create_windows_fallback_process(command, args, env, errlog, cwd)
#     219 except Exception:
#     220     # If creationflags failed, fallback without them
# --> 221     popen_obj = subprocess.Popen(
#     222         [command, *args],
#     223         stdin=subprocess.PIPE,
#     224         stdout=subprocess.PIPE,
#     225         stderr=errlog,
#     226         env=env,
#     227         cwd=cwd,
#     228         bufsize=0,
#     229     )
#     230 return FallbackProcess(popen_obj)
#
# File ~\miniconda3\Lib\subprocess.py:1005, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#     988 # Input and output objects. The general principle is like
#     989 # this:
#     990 #
#    (...)   1000 # are -1 when not using PIPEs. The child objects are -1
#    1001 # when not redirecting.
#    1003 (p2cread, p2cwrite,
#    1004  c2pread, c2pwrite,
# -> 1005  errread, errwrite) = self._get_handles(stdin, stdout, stderr)
#    1007 # From here on, raising exceptions may cause file descriptor leakage
#    1008
#    1009 # We wrap OS handles *before* launching the child, otherwise a
#    1010 # quickly terminating child could make our fds unwrappable
#    1011 # (see #8458).
#
# File ~\miniconda3\Lib\subprocess.py:1422, in Popen._get_handles(self, stdin, stdout, stderr)
#    1420 else:
#    1421     # Assuming file-like object
# -> 1422     errwrite = msvcrt.get_osfhandle(stderr.fileno())
#    1423 errwrite = self._make_inheritable(errwrite)
#
# File ~\kaggle-adk\Lib\site-packages\ipykernel\iostream.py:372, in OutStream.fileno(self)
#     371 msg = "fileno"
# --> 372 raise io.UnsupportedOperation(msg)
#
# UnsupportedOperation: fileno
#
# The above exception was the direct cause of the following exception:
#
# ConnectionError                           Traceback (most recent call last)
# File ~\kaggle-adk\Lib\site-packages\google\adk\tools\mcp_tool\mcp_session_manager.py:117, in retry_on_errors.<locals>.wrapper(self, *args, **kwargs)
#     116 try:
# --> 117   return await func(self, *args, **kwargs)
#     118 except Exception as e:
#     119   # If an error is thrown, we will retry the function to reconnect to the
#     120   # server. create_session will handle detecting and replacing disconnected
#     121   # sessions.
#
# File ~\kaggle-adk\Lib\site-packages\google\adk\tools\mcp_tool\mcp_toolset.py:163, in McpToolset.get_tools(self, readonly_context)
#     162 # Get session from session manager
# --> 163 session = await self._mcp_session_manager.create_session(headers=headers)
#     165 # Fetch available tools from the MCP server
#
# File ~\kaggle-adk\Lib\site-packages\google\adk\tools\mcp_tool\mcp_session_manager.py:375, in MCPSessionManager.create_session(self, headers)
#     372     logger.warning(
#     373         'Error during session creation cleanup: %s', exit_stack_error
#     374     )
# --> 375 raise ConnectionError(f'Failed to create MCP session: {e}') from e
#
# ConnectionError: Failed to create MCP session: fileno
#
# During handling of the above exception, another exception occurred:
#
# NotImplementedError                       Traceback (most recent call last)
# File ~\kaggle-adk\Lib\site-packages\mcp\os\win32\utilities.py:169, in create_windows_process(command, args, env, errlog, cwd)
#     167 try:
#     168     # First try using anyio with Windows-specific flags to hide console window
# --> 169     process = await anyio.open_process(
#     170         [command, *args],
#     171         env=env,
#     172         # Ensure we don't create console windows for each process
#     173         creationflags=subprocess.CREATE_NO_WINDOW  # type: ignore
#     174         if hasattr(subprocess, "CREATE_NO_WINDOW")
#     175         else 0,
#     176         stderr=errlog,
#     177         cwd=cwd,
#     178     )
#     179 except NotImplementedError:
#     180     # If Windows doesn't support async subprocess creation, use fallback
#
# File ~\kaggle-adk\Lib\site-packages\anyio\_core\_subprocesses.py:190, in open_process(command, stdin, stdout, stderr, cwd, env, startupinfo, creationflags, start_new_session, pass_fds, user, group, extra_groups, umask)
#     188     kwargs["umask"] = umask
# --> 190 return await get_async_backend().open_process(
#     191     command,
#     192     stdin=stdin,
#     193     stdout=stdout,
#     194     stderr=stderr,
#     195     cwd=cwd,
#     196     env=env,
#     197     startupinfo=startupinfo,
#     198     creationflags=creationflags,
#     199     start_new_session=start_new_session,
#     200     pass_fds=pass_fds,
#     201     **kwargs,
#     202 )
#
# File ~\kaggle-adk\Lib\site-packages\anyio\_backends\_asyncio.py:2628, in AsyncIOBackend.open_process(cls, command, stdin, stdout, stderr, **kwargs)
#    2627 else:
# -> 2628     process = await asyncio.create_subprocess_exec(
#    2629         *command,
#    2630         stdin=stdin,
#    2631         stdout=stdout,
#    2632         stderr=stderr,
#    2633         **kwargs,
#    2634     )
#    2636 stdin_stream = StreamWriterWrapper(process.stdin) if process.stdin else None
#
# File ~\miniconda3\Lib\asyncio\subprocess.py:224, in create_subprocess_exec(program, stdin, stdout, stderr, limit, *args, **kwds)
#     222 protocol_factory = lambda: SubprocessStreamProtocol(limit=limit,
#     223                                                     loop=loop)
# --> 224 transport, protocol = await loop.subprocess_exec(
#     225     protocol_factory,
#     226     program, *args,
#     227     stdin=stdin, stdout=stdout,
#     228     stderr=stderr, **kwds)
#     229 return Process(transport, protocol, loop)
#
# File ~\miniconda3\Lib\asyncio\base_events.py:1802, in BaseEventLoop.subprocess_exec(self, protocol_factory, program, stdin, stdout, stderr, universal_newlines, shell, bufsize, encoding, errors, text, *args, **kwargs)
#    1801     self._log_subprocess(debug_log, stdin, stdout, stderr)
# -> 1802 transport = await self._make_subprocess_transport(
#    1803     protocol, popen_args, False, stdin, stdout, stderr,
#    1804     bufsize, **kwargs)
#    1805 if self._debug and debug_log is not None:
#
# File ~\miniconda3\Lib\asyncio\base_events.py:539, in BaseEventLoop._make_subprocess_transport(self, protocol, args, shell, stdin, stdout, stderr, bufsize, extra, **kwargs)
#     538 """Create subprocess transport."""
# --> 539 raise NotImplementedError
#
# NotImplementedError:
#
# During handling of the above exception, another exception occurred:
#
# UnsupportedOperation                      Traceback (most recent call last)
# File ~\kaggle-adk\Lib\site-packages\mcp\os\win32\utilities.py:209, in _create_windows_fallback_process(command, args, env, errlog, cwd)
#     207 try:
#     208     # Try launching with creationflags to avoid opening a new console window
# --> 209     popen_obj = subprocess.Popen(
#     210         [command, *args],
#     211         stdin=subprocess.PIPE,
#     212         stdout=subprocess.PIPE,
#     213         stderr=errlog,
#     214         env=env,
#     215         cwd=cwd,
#     216         bufsize=0,  # Unbuffered output
#     217         creationflags=getattr(subprocess, "CREATE_NO_WINDOW", 0),
#     218     )
#     219 except Exception:
#     220     # If creationflags failed, fallback without them
#
# File ~\miniconda3\Lib\subprocess.py:1005, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#     988 # Input and output objects. The general principle is like
#     989 # this:
#     990 #
#    (...)   1000 # are -1 when not using PIPEs. The child objects are -1
#    1001 # when not redirecting.
#    1003 (p2cread, p2cwrite,
#    1004  c2pread, c2pwrite,
# -> 1005  errread, errwrite) = self._get_handles(stdin, stdout, stderr)
#    1007 # From here on, raising exceptions may cause file descriptor leakage
#    1008
#    1009 # We wrap OS handles *before* launching the child, otherwise a
#    1010 # quickly terminating child could make our fds unwrappable
#    1011 # (see #8458).
#
# File ~\miniconda3\Lib\subprocess.py:1422, in Popen._get_handles(self, stdin, stdout, stderr)
#    1420 else:
#    1421     # Assuming file-like object
# -> 1422     errwrite = msvcrt.get_osfhandle(stderr.fileno())
#    1423 errwrite = self._make_inheritable(errwrite)
#
# File ~\kaggle-adk\Lib\site-packages\ipykernel\iostream.py:372, in OutStream.fileno(self)
#     371 msg = "fileno"
# --> 372 raise io.UnsupportedOperation(msg)
#
# UnsupportedOperation: fileno
#
# During handling of the above exception, another exception occurred:
#
# UnsupportedOperation                      Traceback (most recent call last)
# File ~\kaggle-adk\Lib\site-packages\google\adk\tools\mcp_tool\mcp_session_manager.py:341, in MCPSessionManager.create_session(self, headers)
#     339 client = self._create_client(merged_headers)
# --> 341 transports = await asyncio.wait_for(
#     342     exit_stack.enter_async_context(client),
#     343     timeout=timeout_in_seconds,
#     344 )
#     345 # The streamable http client returns a GetSessionCallback in addition to the
#     346 # read/write MemoryObjectStreams needed to build the ClientSession, we limit
#     347 # then to the two first values to be compatible with all clients.
#
# File ~\miniconda3\Lib\asyncio\tasks.py:507, in wait_for(fut, timeout)
#     506 async with timeouts.timeout(timeout):
# --> 507     return await fut
#
# File ~\miniconda3\Lib\contextlib.py:668, in AsyncExitStack.enter_async_context(self, cm)
#     665     raise TypeError(f"'{cls.__module__}.{cls.__qualname__}' object does "
#     666                     f"not support the asynchronous context manager protocol"
#     667                    ) from None
# --> 668 result = await _enter(cm)
#     669 self._push_async_cm_exit(cm, _exit)
#
# File ~\miniconda3\Lib\contextlib.py:214, in _AsyncGeneratorContextManager.__aenter__(self)
#     213 try:
# --> 214     return await anext(self.gen)
#     215 except StopAsyncIteration:
#
# File ~\kaggle-adk\Lib\site-packages\mcp\client\stdio\__init__.py:124, in stdio_client(server, errlog)
#     123     # Open process with stderr piped for capture
# --> 124     process = await _create_platform_compatible_process(
#     125         command=command,
#     126         args=server.args,
#     127         env=({**get_default_environment(), **server.env} if server.env is not None else get_default_environment()),
#     128         errlog=errlog,
#     129         cwd=server.cwd,
#     130     )
#     131 except OSError:
#     132     # Clean up streams if process creation fails
#
# File ~\kaggle-adk\Lib\site-packages\mcp\client\stdio\__init__.py:249, in _create_platform_compatible_process(command, args, env, errlog, cwd)
#     248 if sys.platform == "win32":  # pragma: no cover
# --> 249     process = await create_windows_process(command, args, env, errlog, cwd)
#     250 else:
#
# File ~\kaggle-adk\Lib\site-packages\mcp\os\win32\utilities.py:181, in create_windows_process(command, args, env, errlog, cwd)
#     179 except NotImplementedError:
#     180     # If Windows doesn't support async subprocess creation, use fallback
# --> 181     process = await _create_windows_fallback_process(command, args, env, errlog, cwd)
#     182 except Exception:
#     183     # Try again without creation flags
#
# File ~\kaggle-adk\Lib\site-packages\mcp\os\win32\utilities.py:221, in _create_windows_fallback_process(command, args, env, errlog, cwd)
#     219 except Exception:
#     220     # If creationflags failed, fallback without them
# --> 221     popen_obj = subprocess.Popen(
#     222         [command, *args],
#     223         stdin=subprocess.PIPE,
#     224         stdout=subprocess.PIPE,
#     225         stderr=errlog,
#     226         env=env,
#     227         cwd=cwd,
#     228         bufsize=0,
#     229     )
#     230 return FallbackProcess(popen_obj)
#
# File ~\miniconda3\Lib\subprocess.py:1005, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#     988 # Input and output objects. The general principle is like
#     989 # this:
#     990 #
#    (...)   1000 # are -1 when not using PIPEs. The child objects are -1
#    1001 # when not redirecting.
#    1003 (p2cread, p2cwrite,
#    1004  c2pread, c2pwrite,
# -> 1005  errread, errwrite) = self._get_handles(stdin, stdout, stderr)
#    1007 # From here on, raising exceptions may cause file descriptor leakage
#    1008
#    1009 # We wrap OS handles *before* launching the child, otherwise a
#    1010 # quickly terminating child could make our fds unwrappable
#    1011 # (see #8458).
#
# File ~\miniconda3\Lib\subprocess.py:1422, in Popen._get_handles(self, stdin, stdout, stderr)
#    1420 else:
#    1421     # Assuming file-like object
# -> 1422     errwrite = msvcrt.get_osfhandle(stderr.fileno())
#    1423 errwrite = self._make_inheritable(errwrite)
#
# File ~\kaggle-adk\Lib\site-packages\ipykernel\iostream.py:372, in OutStream.fileno(self)
#     371 msg = "fileno"
# --> 372 raise io.UnsupportedOperation(msg)
#
# UnsupportedOperation: fileno
#
# The above exception was the direct cause of the following exception:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 response = await runner.run_debug("Proporciona una imagen pequeña de ejemplo", verbose=True)
#
# File ~\kaggle-adk\Lib\site-packages\google\adk\runners.py:1168, in Runner.run_debug(self, user_messages, user_id, session_id, run_config, quiet, verbose)
#    1165 if not quiet:
#    1166   print(f'\nUser > {message}')
# -> 1168 async for event in self.run_async(
#    1169     user_id=user_id,
#    1170     session_id=session.id,
#    1171     new_message=types.UserContent(parts=[types.Part(text=message)]),
#    1172     run_config=run_config,
#    1173 ):
#    1174   if not quiet:
#    1175     print_event(event, verbose=verbose)
#
# File ~\kaggle-adk\Lib\site-packages\google\adk\runners.py:505, in Runner.run_async(self, user_id, session_id, invocation_id, new_message, state_delta, run_config)
#     500       await _run_compaction_for_sliding_window(
#     501           self.app, session, self.session_service
#     502       )
#     504 async with Aclosing(_run_with_trace(new_message, invocation_id)) as agen:
# --> 505   async for event in agen:
#     506     yield event
#
# File ~\kaggle-adk\Lib\site-packages\google\adk\runners.py:493, in Runner.run_async.<locals>._run_with_trace(new_message, invocation_id)
#     483       yield event
#     485 async with Aclosing(
#     486     self._exec_with_plugin(
#     487         invocation_context=invocation_context,
#    (...)    491     )
#     492 ) as agen:
# --> 493   async for event in agen:
#     494     yield event
#     495 # Run compaction after all events are yielded from the agent.
#     496 # (We don't compact in the middle of an invocation, we only compact at
#     497 # the end of an invocation.)
#
# File ~\kaggle-adk\Lib\site-packages\google\adk\runners.py:722, in Runner._exec_with_plugin(self, invocation_context, session, execute_fn, is_live_call)
#     719 is_transcribing: bool = False
#     721 async with Aclosing(execute_fn(invocation_context)) as agen:
# --> 722   async for event in agen:
#     723     if is_live_call:
#     724       if event.partial and _is_transcription(event):
#
# File ~\kaggle-adk\Lib\site-packages\google\adk\runners.py:482, in Runner.run_async.<locals>._run_with_trace.<locals>.execute(ctx)
#     480 async def execute(ctx: InvocationContext) -> AsyncGenerator[Event]:
#     481   async with Aclosing(ctx.agent.run_async(ctx)) as agen:
# --> 482     async for event in agen:
#     483       yield event
#
# File ~\kaggle-adk\Lib\site-packages\google\adk\agents\base_agent.py:294, in BaseAgent.run_async(self, parent_context)
#     291   return
#     293 async with Aclosing(self._run_async_impl(ctx)) as agen:
# --> 294   async for event in agen:
#     295     yield event
#     297 if ctx.end_invocation:
#
# File ~\kaggle-adk\Lib\site-packages\google\adk\agents\llm_agent.py:460, in LlmAgent._run_async_impl(self, ctx)
#     458 should_pause = False
#     459 async with Aclosing(self._llm_flow.run_async(ctx)) as agen:
# --> 460   async for event in agen:
#     461     self.__maybe_save_output_to_state(event)
#     462     yield event
#
# File ~\kaggle-adk\Lib\site-packages\google\adk\flows\llm_flows\base_llm_flow.py:370, in BaseLlmFlow.run_async(self, invocation_context)
#     368 last_event = None
#     369 async with Aclosing(self._run_one_step_async(invocation_context)) as agen:
# --> 370   async for event in agen:
#     371     last_event = event
#     372     yield event
#
# File ~\kaggle-adk\Lib\site-packages\google\adk\flows\llm_flows\base_llm_flow.py:389, in BaseLlmFlow._run_one_step_async(self, invocation_context)
#     385 # Preprocess before calling the LLM.
#     386 async with Aclosing(
#     387     self._preprocess_async(invocation_context, llm_request)
#     388 ) as agen:
# --> 389   async for event in agen:
#     390     yield event
#     391 if invocation_context.end_invocation:
#
# File ~\kaggle-adk\Lib\site-packages\google\adk\flows\llm_flows\base_llm_flow.py:500, in BaseLlmFlow._preprocess_async(self, invocation_context, llm_request)
#     497 from ...agents.llm_agent import _convert_tool_union_to_tools
#     499 # Then process all tools from this tool union
# --> 500 tools = await _convert_tool_union_to_tools(
#     501     tool_union,
#     502     ReadonlyContext(invocation_context),
#     503     agent.model,
#     504     multiple_tools,
#     505 )
#     506 for tool in tools:
#     507   await tool.process_llm_request(
#     508       tool_context=tool_context, llm_request=llm_request
#     509   )
#
# File ~\kaggle-adk\Lib\site-packages\google\adk\agents\llm_agent.py:180, in _convert_tool_union_to_tools(tool_union, ctx, model, multiple_tools)
#     177   return [FunctionTool(func=tool_union)]
#     179 # At this point, tool_union must be a BaseToolset
# --> 180 return await tool_union.get_tools_with_prefix(ctx)
#
# File ~\kaggle-adk\Lib\site-packages\google\adk\tools\base_toolset.py:114, in BaseToolset.get_tools_with_prefix(self, readonly_context)
#      98 @final
#      99 async def get_tools_with_prefix(
#     100     self,
#     101     readonly_context: Optional[ReadonlyContext] = None,
#     102 ) -> list[BaseTool]:
#     103   """Return all tools with optional prefix applied to tool names.
#     104
#     105   This method calls get_tools() and applies prefixing if tool_name_prefix is provided.
#    (...)    112     list[BaseTool]: A list of tools with prefixed names if tool_name_prefix is provided.
#     113   """
# --> 114   tools = await self.get_tools(readonly_context)
#     116   if not self.tool_name_prefix:
#     117     return tools
#
# File ~\kaggle-adk\Lib\site-packages\google\adk\tools\mcp_tool\mcp_session_manager.py:123, in retry_on_errors.<locals>.wrapper(self, *args, **kwargs)
#     118 except Exception as e:
#     119   # If an error is thrown, we will retry the function to reconnect to the
#     120   # server. create_session will handle detecting and replacing disconnected
#     121   # sessions.
#     122   logger.info('Retrying %s due to error: %s', func.__name__, e)
# --> 123   return await func(self, *args, **kwargs)
#
# File ~\kaggle-adk\Lib\site-packages\google\adk\tools\mcp_tool\mcp_toolset.py:163, in McpToolset.get_tools(self, readonly_context)
#     157 headers = (
#     158     self._header_provider(readonly_context)
#     159     if self._header_provider and readonly_context
#     160     else None
#     161 )
#     162 # Get session from session manager
# --> 163 session = await self._mcp_session_manager.create_session(headers=headers)
#     165 # Fetch available tools from the MCP server
#     166 timeout_in_seconds = (
#     167     self._connection_params.timeout
#     168     if hasattr(self._connection_params, "timeout")
#     169     else None
#     170 )
#
# File ~\kaggle-adk\Lib\site-packages\google\adk\tools\mcp_tool\mcp_session_manager.py:375, in MCPSessionManager.create_session(self, headers)
#     371   except Exception as exit_stack_error:
#     372     logger.warning(
#     373         'Error during session creation cleanup: %s', exit_stack_error
#     374     )
# --> 375 raise ConnectionError(f'Failed to create MCP session: {e}') from e
#
# ConnectionError: Failed to create MCP session: fileno

# %% [markdown]
# ***Codigo Correcto, pero no soportable en Ipython, o en Jupyter..hay que correrlo en archivos.py***
